# %%
# 感知机：给定输入x，权重w，偏移b，感知机输出：o=sigma(<w, x>+b> sigma(x)=1 if x>0; 0 otherwise
# 二分类：-1或1，vs.回归输出实数，vs.softmax输出概率
# 训练感知机：
# initialize w=0 and b=0
# repeat
#     if yi[<w, xi> + b] <= 0 then
#         w <- w + yi xi and b <- b+yi
#     end if
# until all classified correctly
# 等价于使用批量大小为1的梯度下降
# 并使用如下的损失函数
# l(y,x,w)=max(0, -y<w,x>)

# 收敛定理
# 数据在半径r内
# 余量p分类两类
# y(xTw+b)>=p
# 对于||w||^2+b^2<=1
# 感知机保证在(r^2+1)/p^2步后收敛

# XOR问题
# 感知机不能拟合XOR函数，它只能产生线性分割面

# 总结：
# 感知机是一个二分类模型，是最早的AI模型之一
# 它的求解算法等价于使用批量大小为1的梯度下降
# 它不能拟合XOR函数，导致第一次的AI寒冬



# 多层感知机
# 学习XOR：
# ![XOR Coordinate](deep_learning/image/XOR.png)
# from IPython.display import Image, display
# display(Image('./image/XOR.png', width=300))
# display(Image('./image/XOR_PRODUCT.png', width=300))
from IPython.display import Image, display, HTML

# 创建一个 HTML 表格，将两张图片并列显示
html_code = """
<table>
  <tr>
    <td><img src="./image/XOR.png" width="300"></td>
    <td><img src="./image/XOR_PRODUCT.png" width="300"></td>
  </tr>
</table>
"""

display(HTML(html_code))
# Out:
# <table>
#   <tr>
#     <td><img src="./image/XOR.png" width="300"></td>
#     <td><img src="./image/XOR_PRODUCT.png" width="300"></td>
#   </tr>
# </table>
