# %%
import os
os.makedirs(os.path.join('..', 'data'), exist_ok=True)
data_file = os.path.join('..', 'data', 'house_tiny.csv')
with open(data_file, 'w') as f:
    f.write('NumRooms,Alley,Price\n') #列名
    f.write('NA,Pave,127500\n')       #每行表示一个数据样本
    f.write('2,NA,106000\n')
    f.write('4,NA,178100\n')
    f.write('NA,NA,140000\n')

# %%
import pandas as pd
data = pd.read_csv(data_file)
data
# Out:
#    NumRooms Alley   Price
# 0       NaN  Pave  127500
# 1       2.0   NaN  106000
# 2       4.0   NaN  178100
# 3       NaN   NaN  140000

# %%
print(data)
# Out:
#    NumRooms Alley   Price
# 0       NaN  Pave  127500
# 1       2.0   NaN  106000
# 2       4.0   NaN  178100
# 3       NaN   NaN  140000

# %%
# 插值
inputs, outputs = data.iloc[:, 0:2], data.iloc[:, 2]
inputs.iloc[:, 0] = inputs.select_dtypes(include=['number']).fillna(inputs.select_dtypes(include=['number']).mean())
print(inputs)
# Out:
#    NumRooms Alley
# 0       3.0  Pave
# 1       2.0   NaN
# 2       4.0   NaN
# 3       3.0   NaN

# %%
inputs = pd.get_dummies(inputs, dummy_na=True)
print(inputs)
# Out:
#    NumRooms  Alley_Pave  Alley_nan
# 0       3.0        True      False
# 1       2.0       False       True
# 2       4.0       False       True
# 3       3.0       False       True

# %%
print(inputs.dtypes)
# Out:
# NumRooms      float64
# Alley_Pave       bool
# Alley_nan        bool
# dtype: object

# %%
# print(inputs.values)
# print(inputs.values.dtype)
# Out:
# [[3.0 True False]
#  [2.0 False True]
#  [4.0 False True]
#  [3.0 False True]]
# object

# %%
outputs
# Out:
# 0    127500
# 1    106000
# 2    178100
# 3    140000
# Name: Price, dtype: int64

# %%
import numpy as np
import torch
X,y = torch.tensor(inputs.values, dtype=torch.float32), torch.tensor(outputs.values)
X,y
X.dtype

# X, y = torch.tensor(inputs.to_numpy().astype(np.float32)), torch.tensor(outputs.values)
# X, y

# inputs = inputs.astype(np.float32)
# X, y = torch.tensor(inputs.valus), torch.tensor(outputs.values)
# X, y
# Out:
# torch.float32
