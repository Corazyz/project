# %%
import torch
x = torch.arange(4.0)
x
# Out:
# tensor([0., 1., 2., 3.])

# %%
x.requires_grad_(True) # 等价于 x = torch.arange(4.0, requires_grad=True)
x.grad # 默认值是none

# %%
y = 2 * torch.dot(x, x)
y
# Out:
# tensor(28., grad_fn=<MulBackward0>)

# %%
y.backward()
x.grad
# Out:
# tensor([ 0.,  4.,  8., 12.])

# %%
# 默认情况下，pytorch会累积梯度，需要清除之前的值
x.grad.zero_()
y = x.sum()
y.backward()
x.grad
# Out:
# tensor([1., 1., 1., 1.])

# %%
x.grad.zero_()
y = x * x
# 等价于y.backward(torch.ones(len(x))
# y.sum().backward()
y.backward(torch.ones(len(x)))
x, x.grad
# Out:
# (tensor([0., 1., 2., 3.], requires_grad=True), tensor([0., 2., 4., 6.]))

# %%
# 将某些计算移动到记录的计算图之外
x.grad.zero_()
y = x * x
u = y.detach()
z = u * x

z.sum().backward()
x.grad == u
# Out:
# tensor([True, True, True, True])

# %%
x.grad.zero_()
y.sum().backward()
x.grad == 2 * x
# Out:
# tensor([True, True, True, True])

# %%
def f(a):
    b = a * 2
    while b.norm() < 1000:
        b = b * 2
    if b.sum() > 0:
        c = b
    else:
        c = 100 * b
    return c

a = torch.randn(size=(), requires_grad=True)
d = f(a)
d.backward()

a, a.grad, d, a.grad == d/a
# Out:
# (tensor(1.3500, requires_grad=True),
#  tensor(1024.),
#  tensor(1382.3618, grad_fn=<MulBackward0>),
#  tensor(True))
